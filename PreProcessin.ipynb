# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Final_Train_Dataset.csv")
df.head()
# Out:
#    Unnamed: 0 experience                                    job_description  \
# 0           0    5-7 yrs  Exp: Minimum 5 years;Good understanding of IOC...
# 1           1  10-17 yrs  He should have handled a team of atleast 5-6 d...
# 2           2    5-9 yrs  Must be an effective communicator (written & s...
# 3           3   7-10 yrs  7  -  10 years of overall experience in data e...
# 4           4    1-3 yrs  Chartered Accountancy degree or MBA in Finance...
#
#                                            job_desig   job_type  \
# 0        Senior Exploit and Vulnerability Researcher        NaN
# 1                                           Head SCM        NaN
# 2  Deputy Manager - Talent Management & Leadershi...  Analytics
# 3                 Associate Manager Data Engineering  Analytics
# 4                            TS- GSA- Senior Analyst        NaN
#
#                                           key_skills               location  \
# ...

# %%
df['LowExp'], df['HighExp'] = df['experience'].str.split('-',1).str

# %%
df['HighExp'] = df['HighExp'].str.replace(" yrs","")
df.head()
# Out:
#    Unnamed: 0 experience                                    job_description  \
# 0           0    5-7 yrs  Exp: Minimum 5 years;Good understanding of IOC...
# 1           1  10-17 yrs  He should have handled a team of atleast 5-6 d...
# 2           2    5-9 yrs  Must be an effective communicator (written & s...
# 3           3   7-10 yrs  7  -  10 years of overall experience in data e...
# 4           4    1-3 yrs  Chartered Accountancy degree or MBA in Finance...
#
#                                            job_desig   job_type  \
# 0        Senior Exploit and Vulnerability Researcher        NaN
# 1                                           Head SCM        NaN
# 2  Deputy Manager - Talent Management & Leadershi...  Analytics
# 3                 Associate Manager Data Engineering  Analytics
# 4                            TS- GSA- Senior Analyst        NaN
#
#                                           key_skills               location  \
# ...

# %%
df['LowSal'], df['HighSal'] = df['salary'].str.split('to',1).str
df.head(3)
# Out:
#    Unnamed: 0 experience                                    job_description  \
# 0           0    5-7 yrs  Exp: Minimum 5 years;Good understanding of IOC...
# 1           1  10-17 yrs  He should have handled a team of atleast 5-6 d...
# 2           2    5-9 yrs  Must be an effective communicator (written & s...
#
#                                            job_desig   job_type  \
# 0        Senior Exploit and Vulnerability Researcher        NaN
# 1                                           Head SCM        NaN
# 2  Deputy Manager - Talent Management & Leadershi...  Analytics
#
#                                           key_skills               location  \
# 0  team skills, communication skills, analytical ...  Delhi NCR(Vikas Puri)
# 1  ppc, logistics, inventory management, supply c...                Sonepat
# 2  HR Analytics, Employee Engagement, Training, S...              Delhi NCR
#
#    salary  company_name_encoded LowExp HighExp LowSal HighSal
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# experience                  0
# job_description          4418
# job_desig                   0
# job_type                15005
# key_skills                  1
# location                    0
# salary                      0
# company_name_encoded        0
# LowExp                      0
# HighExp                     0
# LowSal                      0
# HighSal                     0
# dtype: int64

# %%
df = df.drop(['Unnamed: 0','experience', 'job_type', 'salary'], axis= 1)

# %%
df.isnull().sum()
# Out:
# job_description         4418
# job_desig                  0
# key_skills                 1
# location                   0
# company_name_encoded       0
# LowExp                     0
# HighExp                    0
# LowSal                     0
# HighSal                    0
# dtype: int64

# %%
df = df[pd.notnull(df['key_skills'])]

# %%
k = df['key_skills'].str[:-1].str.split(',', expand=True)

# %%
k.head()
# Out:
#              0                      1                      2   \
# 0   team skills   communication skills      analytical skills
# 1           ppc              logistics   inventory management
# 2  HR Analytics    Employee Engagement               Training
# 3           SQL             Javascript             Automation
# 4    accounting                finance              cash flow
#
#                          3                     4           5   \
# 0         problem solving..                  None        None
# 1   supply chain management           procurement          ..
# 2     Succession Planning..                  None        None
# 3                    Python                  Ruby   Analytics
# 4        financial planning   statutory accountin        None
#
#                     6     7     8     9     10    11
# 0                 None  None  None  None  None  None
# 1                 None  None  None  None  None  None
# 2                 None  None  None  None  None  None
# ...

# %%
k.nunique()
# Out:
# 0     4134
# 1     4669
# 2     5443
# 3     5550
# 4     4140
# 5     2428
# 6     1268
# 7      666
# 8      300
# 9      127
# 10      12
# 11       2
# dtype: int64

# %%
B = []
for i in range(12) :
    B.append(k[i].unique())

# %%
import itertools

merged = list(itertools.chain.from_iterable(B))

# %%
merged
# Out:
# ['team skills',
#  'ppc',
#  'HR Analytics',
#  'SQL',
#  'accounting',
#  'academics',
#  'Fraud Analytics',
#  'Accounting',
#  'esic',
#  'accounting standards',
#  'Test Data',
#  'Banking',
#  'Marketing Automation',
#  'Data Science',
#  'Budgeting',
#  'Spring',
#  'Hadoop',
#  'Business Finance',
#  'Information Retrieval',
#  'Digital Marketing',
#  'Business Analyst - Gurgaon',
#  'Business Continuity',
#  'project implementation',
#  'AR',
#  'manual testing',
#  'Sales',
#  'amazon',
#  'finance',
#  'Analytics',
#  'Life Insurance',
#  'Machine Learning',
#  'Javascript',
#  'Selenium',
#  'Finance',
#  'spark',
#  'digital marketing',
#  'matlab',
#  'Head - Online Marketing',
#  'competitive analysis',
#  'ITIL',
#  'cold calling',
#  'saltstack',
#  'SQL Server',
#  'SEO',
#  'Static Timing Analysis',
#  'project planning',
#  'Collections Strategy',
#  'XML',
#  'market risk',
#  'Product Consultant',
#  'Inventory Management',
#  'Accounting Operations',
# ...

# %%
used = []
unique = [used.append(x) for x in merged if x not in used]

# %%
used = [i for i in used if i is not None]

# %%
len(used)
# Out:
# 19156

# %%
df.text.apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' RTR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head(3)
